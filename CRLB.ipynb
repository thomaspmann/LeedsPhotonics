# %% [markdown]
# On-the-ﬂy decoding luminescence lifetimes inthe microsecond region for lanthanide-encodedsuspension arrays
# http://www.readcube.com/articles/10.1038%2Fncomms4741

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 5.0)

from numpy import exp

# %% [markdown]
# # Evaluate CRLB(tau)

# %%
tau = 10  # Luminescence lifetime
T = tau/0.5  # Detection channel width
M = np.linspace(1*tau/T,100*tau/T,num=5000)  # Detection channels

# %%
def CRLB(tau,T,M):
    a = (T**2/tau**2)
    b = exp(T/tau)/(exp(T/tau)-1)**2
    c = (M**2*exp(M*T/tau)) / ((exp(M*T/tau)-1)**2)

    return 1/(a*(b-c))

# %%
# log x and y axis
plt.subplot(111)
plt.loglog(M*T/tau, CRLB(tau,T,M),'-',label='T='++'tau')
plt.grid(True, which="both")
plt.xlabel('MT/tau')
plt.ylabel('EN*CRLB(tau)/tau**2')
plt.ylim(1,100)
plt.legend(loc='best')

# %%
CRLB(tau,T,M)[-1]
# Out:
# 1.3810978455418157

# %% [markdown]
# ### Loop and plot for various T widths

# %%
def CRLB_norm(T,M):
    a = (T**2)
    b = exp(T)/(exp(T)-1)**2
    c = (M**2*exp(M*T)) / ((exp(M*T)-1)**2)

    return 1/(a*(b-c))

# %%
# log x and y axis
plt.subplot(111)

# Loop through various T/tau values
for T in [2,1,1/2,1/4,1/8]:
    M = np.linspace(1/T,100/T,num=5000)  # Detection channels
    
    plt.loglog(M*T, CRLB_norm(T,M),'-',label='T= '+ str(T_multi)+' tau')
    
plt.grid(True, which="both")
plt.xlabel('MT/tau')
plt.ylabel('$\\frac{CRLB(tau)}{tau**2} EN$')
plt.ylim(1,100)
plt.xlim(1,100)
plt.legend(loc='best')
# Out:
# C:\Users\mn14tm\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:6: RuntimeWarning: divide by zero encountered in true_divide

# %% [markdown]
# Note that the normalised variance tends to 1 (tau), which is the theoretical variance of a poisson process.

# %% [markdown]
# # Monte Carlo Simulation
